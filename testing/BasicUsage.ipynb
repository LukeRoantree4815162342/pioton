# %%
from pioton import píotón_magic, píotón_notebook, show_syntax

# %%
# %%píotón
#
# do achan i sa [1,2,3]:
#   scríobh(i)
# Out:
# UsageError: Cell magic `%%píotón` not found.

# %%
píotón_magic()

# %%
# %%píotón
#
# do achan i sa [1,2,3]:
#   scríobh(i)
# Out:
# 1
# 2
# 3

# %%
do achan i sa [1,2,3]:
  scríobh(i)
# Out:
#   Cell In[5], line 1
#     do achan i sa [1,2,3]:
#        ^
# SyntaxError: invalid syntax

# %%
píotón_notebook()
# Out:
# ...
#     You're using píotón, a tool to write IPython code as Gaeilge.
#     Call pioton.show_syntax() to see the new syntax provided.
#     This wasn't built to be robust, so we don't recommend it for
#     anything important. If you still want to use it for anything
#     important knowing this, go have a wee word with yourself.

# %%
do achan i sa [1,2,3]:
  scríobh(i)
# Out:
# 1
# 2
# 3

# %%
! echo "scríobh('\n\nhello world')" > test.pag && rm test.pag.py
! cat test.pag
! tiomsaitheoir test.pag
! cat test.pag.py
! python test.pag.py
# Out:
# scríobh('\n\nhello world')
# Ag seiceáil na comhaid... | Checking the files...
# Ag tosú... | Starting...
# Rinne é le test.pag | Done with test.pag
# print('\n\nhello world')
#
#
# hello world

# %%
show_syntax()
# Out:
# print(x)                       --> scríobh(x)
#
# for i in y:                    --> do achan i sa y:
#
# while (condition)              --> nuair (condition):
#
# and                            --> agus
#
# or                             --> nó
#
# True, False                    --> Fíor, Bréagach
#
# not                            --> níl
#
# is                             --> céanna
#
# def func(x):                   --> func(x) a sainigh:
#
# if (condition):                --> dá (condition):
#
# elif (condition):              --> seachas dá (condition):
#
# else:                          --> seachas:
#
# with x() as y:                 --> glac x() ag cosiul le y:
#
# open()                         --> oscail()
#
# f.close()                      --> f.druid()
#
# None                           --> Rud Ar Bíth
#
# assert (cond)                  --> seiceáil (condition)
#
# from x import y                --> ó x tóg isteach y
#
# ...
